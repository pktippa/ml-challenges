# %%
from pathlib import Path
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split

# %%
# Reading it from csv using pandas
patient_monthwise_revenue_test = pd.read_csv('data/patient_monthwise_revenue_test.csv')
# Out:
# d:\softs\anaconda3\envs\portea\lib\site-packages\IPython\core\interactiveshell.py:2728: DtypeWarning: Columns (19) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
# Importing all other files
patient_monthwise_revenue_train = pd.read_csv('data/patient_monthwise_revenue_train.csv')
physio_diagnosis_train = pd.read_csv('data/physio_diagnosis_train.csv')
physio_appts_train = pd.read_csv('data/physio_appts_train.csv')
patient_train_classified = pd.read_csv('data/patient_train_classified.csv')
physio_diagnosis_test = pd.read_csv('data/physio_diagnosis_test.csv')
# Out:
# d:\softs\anaconda3\envs\portea\lib\site-packages\IPython\core\interactiveshell.py:2728: DtypeWarning: Columns (20,21) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
patient_monthwise_revenue_train.head()
# Out:
#    patient_id visit_month_year  service_id  visits_count     city  revenue  \
# 0       10020            04/15           2             1  Chennai    500.0
# 1       10293            04/17           2             7   Mumbai   4900.0
# 2       10381            07/15           2             1      NCR    500.0
# 3       10381            08/15           2            20      NCR   9500.0
# 4       10381            08/15          98             1      NCR      0.0
#
#   ref_type  ref_name      ref_source service_name     ...     FVS approx_age  \
# 0      B2C      None  Direct Organic            P     ...       P         62
# 1      B2C  Facebook   Digital + ATL            P     ...       P         42
# 2      B2C      None  Direct Organic            P     ...       P         67
# 3      B2C      None  Direct Organic            P     ...       P         67
# 4      B2C      None  Direct Organic            P     ...       P         67
#
#    gender         LVD   brand visits_required  \
# 0    male  21/04/2015  Portea               1
# 1  female  25/04/2017  Portea               8
# 2    male  11/09/2015  Portea              10
# 3    male  11/09/2015  Portea              10
# 4    male  11/09/2015  Portea              10
#
#                                            diagnosis  avg_nps Unnamed: 20  \
# 0  Post Operative condition of Cardiac Valve repl...       \N         NaN
# 1                               Rheumatoid arthritis        9         NaN
# 2                                    frozen shoulder        8         NaN
# 3                                    frozen shoulder        8         NaN
# 4                                    frozen shoulder        8         NaN
#
#   Unnamed: 21
# 0         NaN
# 1         NaN
# 2         NaN
# 3         NaN
# 4         NaN
#
# [5 rows x 22 columns]

# %%
patient_monthwise_revenue_train.count()
# Out:
# patient_id          83307
# visit_month_year    83307
# service_id          83307
# visits_count        83307
# city                83307
# revenue             83307
# ref_type            83307
# ref_name            83307
# ref_source          83307
# service_name        82084
# FVD                 83307
# FVM                 83307
# FVS                 83307
# approx_age          83307
# gender              83274
# LVD                 83307
# brand               83307
# visits_required     83307
# diagnosis           81574
# avg_nps             83307
# Unnamed: 20            40
# Unnamed: 21            16
# dtype: int64

# %%
# patient_id is marked as patientid - this need to be renamed
physio_diagnosis_train.head()
# Out:
#    patientId                                          diagnosis  \
# 0      10020  Post Operative condition of Cardiac Valve repl...
# 1      10293                               Rheumatoid arthritis
# 2      10381                                    frozen shoulder
# 3      10388            Osteoarthritis,Bilateral Osteoarthritis
# 4      10611  periarthritis shoulder (Right side),frozen sho...
#
#          Service  Appt_id AGE  gender         LVD Unnamed: 7 Unnamed: 8
# 0  physiotherapy   432155  62    male  21/04/2015        NaN        NaN
# 1  physiotherapy  2617156  42  female  25/04/2017        NaN        NaN
# 2  physiotherapy   675822  67    male  11/09/2015        NaN        NaN
# 3  physiotherapy   783936  75  female  28/04/2017        NaN        NaN
# 4  physiotherapy  1083765  63    male  22/01/2016        NaN        NaN

# %%
physio_diagnosis_train = physio_diagnosis_train.rename(columns={'patientId': 'patient_id'})
physio_diagnosis_train.head()
# Out:
#    patient_id                                          diagnosis  \
# 0       10020  Post Operative condition of Cardiac Valve repl...
# 1       10293                               Rheumatoid arthritis
# 2       10381                                    frozen shoulder
# 3       10388            Osteoarthritis,Bilateral Osteoarthritis
# 4       10611  periarthritis shoulder (Right side),frozen sho...
#
#          Service  Appt_id AGE  gender         LVD Unnamed: 7 Unnamed: 8
# 0  physiotherapy   432155  62    male  21/04/2015        NaN        NaN
# 1  physiotherapy  2617156  42  female  25/04/2017        NaN        NaN
# 2  physiotherapy   675822  67    male  11/09/2015        NaN        NaN
# 3  physiotherapy   783936  75  female  28/04/2017        NaN        NaN
# 4  physiotherapy  1083765  63    male  22/01/2016        NaN        NaN

# %%
physio_diagnosis_train.count()
# Out:
# patient_id    48804
# diagnosis     47748
# Service       48804
# Appt_id       48803
# AGE           48804
# gender        48775
# LVD           48804
# Unnamed: 7       18
# Unnamed: 8        2
# dtype: int64

# %%
# Merging/Joining patient_monthwise_revenue_train and physio_diagnosis_train on column match of 'patient_id'
md_monthwise_revenue_physio_diagnosis_train = pd.merge(patient_monthwise_revenue_train, physio_diagnosis_train, on='patient_id')
md_monthwise_revenue_physio_diagnosis_train.head()
# Out:
#    patient_id visit_month_year  service_id  visits_count     city  revenue  \
# 0       10020            04/15           2             1  Chennai    500.0
# 1       10293            04/17           2             7   Mumbai   4900.0
# 2       10381            07/15           2             1      NCR    500.0
# 3       10381            08/15           2            20      NCR   9500.0
# 4       10381            08/15          98             1      NCR      0.0
#
#   ref_type  ref_name      ref_source service_name    ...     Unnamed: 20  \
# 0      B2C      None  Direct Organic            P    ...             NaN
# 1      B2C  Facebook   Digital + ATL            P    ...             NaN
# 2      B2C      None  Direct Organic            P    ...             NaN
# 3      B2C      None  Direct Organic            P    ...             NaN
# 4      B2C      None  Direct Organic            P    ...             NaN
#
#   Unnamed: 21                                        diagnosis_y  \
# 0         NaN  Post Operative condition of Cardiac Valve repl...
# 1         NaN                               Rheumatoid arthritis
# 2         NaN                                    frozen shoulder
# 3         NaN                                    frozen shoulder
# 4         NaN                                    frozen shoulder
#
#          Service  Appt_id AGE gender_y       LVD_y Unnamed: 7 Unnamed: 8
# 0  physiotherapy   432155  62     male  21/04/2015        NaN        NaN
# 1  physiotherapy  2617156  42   female  25/04/2017        NaN        NaN
# 2  physiotherapy   675822  67     male  11/09/2015        NaN        NaN
# 3  physiotherapy   675822  67     male  11/09/2015        NaN        NaN
# 4  physiotherapy   675822  67     male  11/09/2015        NaN        NaN
#
# [5 rows x 30 columns]

# %%
md_monthwise_revenue_physio_diagnosis_train.count()
# Out:
# patient_id          83307
# visit_month_year    83307
# service_id          83307
# visits_count        83307
# city                83307
# revenue             83307
# ref_type            83307
# ref_name            83307
# ref_source          83307
# service_name        82084
# FVD                 83307
# FVM                 83307
# FVS                 83307
# approx_age          83307
# gender_x            83274
# LVD_x               83307
# brand               83307
# visits_required     83307
# diagnosis_x         81574
# avg_nps             83307
# Unnamed: 20            40
# Unnamed: 21            16
# diagnosis_y         81570
# Service             83307
# Appt_id             83292
# AGE                 83307
# gender_y            83274
# LVD_y               83307
# Unnamed: 7             43
# Unnamed: 8             16
# dtype: int64

# %%
# here the patient id is named as pat_id, this need to be renamed
physio_appts_train.head()
# Out:
#    appt_id  pat_id        startDateTime  serviceId           name     status  \
# 0      629   10020  2013-11-25 11:00:00          2  Physiotherapy  cancelled
# 1     2257   10293  2013-12-21 16:30:00          2  Physiotherapy  cancelled
# 2     2719   10381  2014-01-02 11:30:00          2  Physiotherapy  cancelled
# 3     2785   10388  2014-01-04 10:00:00          2  Physiotherapy  cancelled
# 4     2927   10381  2014-01-02 11:30:00          2  Physiotherapy  cancelled
#
#     cost  discount patient_ivr_confirmation  appointment_delayed
# 0    0.0       0.0                       \N                    0
# 1  600.0      50.0                       \N                    0
# 2  550.0       0.0                       \N                    0
# 3    0.0       0.0                       \N                    0
# 4  550.0       0.0                       \N                    0

# %%
physio_appts_train = physio_appts_train.rename(columns={'pat_id': 'patient_id'})
physio_appts_train.head()
# Out:
#    appt_id  patient_id        startDateTime  serviceId           name  \
# 0      629       10020  2013-11-25 11:00:00          2  Physiotherapy
# 1     2257       10293  2013-12-21 16:30:00          2  Physiotherapy
# 2     2719       10381  2014-01-02 11:30:00          2  Physiotherapy
# 3     2785       10388  2014-01-04 10:00:00          2  Physiotherapy
# 4     2927       10381  2014-01-02 11:30:00          2  Physiotherapy
#
#       status   cost  discount patient_ivr_confirmation  appointment_delayed
# 0  cancelled    0.0       0.0                       \N                    0
# 1  cancelled  600.0      50.0                       \N                    0
# 2  cancelled  550.0       0.0                       \N                    0
# 3  cancelled    0.0       0.0                       \N                    0
# 4  cancelled  550.0       0.0                       \N                    0

# %%
physio_appts_train.count()
# Out:
# appt_id                     501324
# patient_id                  501324
# startDateTime               501324
# serviceId                   501324
# name                        501324
# status                      501324
# cost                        501324
# discount                    501324
# patient_ivr_confirmation    501324
# appointment_delayed         501324
# dtype: int64

# %%
# here the patient id is named as PID, this need to be renamed
patient_train_classified.head()
# Out:
#       PID Bucket  Revenue
# 0  400061    Med   1200.0
# 1   25535   High  25150.0
# 2  409013    Med   4480.0
# 3  164585    Low    500.0
# 4   56960    Low    500.0

# %%
patient_train_classified = patient_train_classified.rename(columns={'PID': 'patient_id'})
patient_train_classified.head()
# Out:
#    patient_id Bucket  Revenue
# 0      400061    Med   1200.0
# 1       25535   High  25150.0
# 2      409013    Med   4480.0
# 3      164585    Low    500.0
# 4       56960    Low    500.0

# %%
patient_train_classified.count()
# Out:
# patient_id    48804
# Bucket        48804
# Revenue       48804
# dtype: int64
